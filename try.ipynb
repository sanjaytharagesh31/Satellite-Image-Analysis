# %%
from io import BytesIO
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
uploaded = files.upload()
im = Image.open(BytesIO(uploaded['ch.png']))
photo_data = np.array(im)
plt.imshow(photo_data)
# Out:
#      <input type="file" id="files-0a6f1224-6146-4d52-b7fd-b4269f7c70c8" name="files[]" multiple disabled />
#      <output id="result-0a6f1224-6146-4d52-b7fd-b4269f7c70c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ch.png to ch (2).png

# %%
type(photo_data)
# Out:
# numpy.ndarray

# %%
from skimage import data

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
photo_data.shape
# Out:
# (685, 887, 4)

# %%
photo_data.size
# Out:
# 2430380

# %%
photo_data.min(),photo_data.max()
# Out:
# (0, 255)

# %%
photo_data.mean()
# Out:
# 127.17324081007908

# %%
photo_data[150,250]
# Out:
# array([ 13,  93, 240, 255], dtype=uint8)

# %%
photo_data[150,250,1]
# Out:
# 93

# %%
photo_data[150,250] = 0
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
photo_data[200:800, : ,1] = 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
photo_data[200:800, :] = 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
photo_data[200:800, :] = 0
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
from io import BytesIO
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
uploaded = files.upload()
im = Image.open(BytesIO(uploaded['ch.png']))
photo_data = np.array(im)
plt.imshow(photo_data)
# Out:
#      <input type="file" id="files-dcffc8c1-706c-4b39-bcea-2b11ce378988" name="files[]" multiple disabled />
#      <output id="result-dcffc8c1-706c-4b39-bcea-2b11ce378988">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ch.png to ch (3).png

# %%
print("Shape of photo_data:", photo_data.shape)
low_value_filter = photo_data < 200
#print(low_value_filter)
print("Shape of low_value_filter:", low_value_filter.shape)
# Out:
# Shape of photo_data: (685, 887, 4)
# Shape of low_value_filter: (685, 887, 4)
